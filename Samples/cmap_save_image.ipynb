# %%
# %cd ..
# Out:
# d:\work\ADASVehicleTracking

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from utils import readImage, props, save_image_cmap

# %%
filename = 'D:\work\ADASVehicleTracking\Data\DSC_1643.jpg'

# %%
data = readImage(image_path=filename, grayscale=True, convert_BGR2RGB=False)
props(data)
# Out:
# Shape : (578, 872) Maximum : 255 Minimum : 5 Data Type : uint8

# %%
save_image_cmap(data, title="Test_DSC_1643")

# %%
# # some data (512x512)
# import scipy.misc
# data = scipy.misc.lena()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18200/423172209.py in <module>
#       1 # some data (512x512)
#       2 import scipy.misc
# ----> 3 data = scipy.misc.lena()
#
# AttributeError: module 'scipy.misc' has no attribute 'lena'

# %%
dir(plt.cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'LUTSIZE',
#  'MutableMapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
# ...

# %%
# a colormap and a normalization instance
cmap = plt.cm.jet
norm = plt.Normalize(vmin=data.min(), vmax=data.max())

# map the normalized data to colors
# image is now RGBA (512x512x4) 
image = cmap(norm(data))

# %%
props(image)
# Out:
# Shape : (578, 872, 4) Maximum : 1.0 Minimum : 0.0 Data Type : float64

# %%
plt.imshow(image)

# %%
cv2.imwrite('lena.png', image.astype(np.uint8))
# Out:
# True
