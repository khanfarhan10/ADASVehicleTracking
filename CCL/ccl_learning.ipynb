# %%
# %cd ..
# Out:
# c:\Users\joyde\OneDrive\Desktop\TAMESH DA\aaaa

# %%
import cv2
from utils import readImage, props, show_image

# %%
filename = r'C:\Users\joyde\OneDrive\Desktop\TAMESH DA\aaaa\ADASVehicleTracking-main\Data\DSC_1643.jpg'
img = readImage(filename, grayscale=True)
props(img)
# Out:
# Shape : (578, 872) Maximum : 255 Minimum : 5 Data Type : uint8

# %%
show_image(img, title = "DSC_1643_GrayScale")

# %%
thresh_val, thresh_img = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
props(thresh_img)
# Out:
# Shape : (578, 872) Maximum : 255 Minimum : 0 Data Type : uint8

# %%
connectivity = 4 # or 8
(numLabels, labels, stats, centroids) = cv2.connectedComponentsWithStats(thresh_img, connectivity, cv2.CV_32S)

# %%
numLabels
# Out:
# 1119

# %%
props(stats)
# Out:
# Shape : (1119, 5) Maximum : 250537 Minimum : 0 Data Type : int32

# %%
props(centroids)
# Out:
# Shape : (1119, 2) Maximum : 871.0 Minimum : 0.0 Data Type : float64

# %%
props(labels, show_uniques=True)
# Out:
# Shape : (578, 872) Maximum : 1118 Minimum : 0 Data Type : int32
# Uniques : [   0    1    2 ... 1116 1117 1118]

# %%
new_labels = labels/ labels.max() * 255
props(new_labels)
show_image(new_labels)
# Out:
# Shape : (578, 872) Maximum : 255.0 Minimum : 0.0 Data Type : float64
